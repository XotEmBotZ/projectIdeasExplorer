# %%
import uvicorn
from fastapi import FastAPI
import pandas as pd
import requests
import bs4
from pprint import pprint

# %%
res=requests.get("https://sih.gov.in/sih2023PS")
soup=bs4.BeautifulSoup(res.text,"html.parser")

# %%
table=soup.find("table",{"id":"dataTablePS"})

# %%
tr=table.find("tbody").findChildren(recursive=False)

# %%
data={}
for row in tr:
    # row=table.find("tbody").find("tr",recursive=False)
    columns=row.find_all("td",recursive=False)
    data[columns[4].text]={
        "title":columns[2].find("a").text.strip(),
        "category":columns[3].text.strip(),
        "organization":columns[1].text.strip(),
        "domainBucket":columns[6].text.strip(),
        "submisions":columns[5].text.strip(),
        "description":columns[2].find_all("td")[2].find("div",class_="style-2").text.strip(),
        "youtubeLink":columns[2].find_all("td")[6].text.strip(),
        "datasetLink":columns[2].find_all("td")[7].text.strip(),
    }

# %%
len(data)
# Out:
# 239

# %%
df=pd.DataFrame(data)
df=df.transpose()
df["submisions"]=df["submisions"].astype("int")
df
# Out:
#                                                      title  category  \
# SIH1278  International Comparative System to Launch Int...  Software
# SIH1279  Development of software for streamlining the l...  Software
# SIH1280  Development of e-Portal for facilitating Case ...  Software
# SIH1281  Development of gamified platform on Children's...  Software
# SIH1282  Tech-Driven Solutions for Undertrial Prisoners...  Software
# ...                                                    ...       ...
# SIH1512  Centralized Monitoring System for Street Light...  Hardware
# SIH1513  Effective management of construction and demol...  Hardware
# SIH1514  Comprehensive lnspection and Analysis of Water...  Software
# SIH1515  Smart and Effective realtime Management of str...  Software
# SIH1516  Suggest an Al-based solution to enable ease of...  Software
#
#                                   organization              domainBucket  \
# SIH1278  Ministry of Chemicals and Fertilizers             Miscellaneous
# SIH1279            Ministry of Law and Justice             Miscellaneous
# SIH1280            Ministry of Law and Justice             Miscellaneous
# SIH1281            Ministry of Law and Justice           Smart Education
# SIH1282            Ministry of Law and Justice             Miscellaneous
# ...                                        ...                       ...
# SIH1512  Ministry of Housing and Urban Affairs          Smart Automation
# SIH1513  Ministry of Housing and Urban Affairs  Clean & Green Technology
# SIH1514  Ministry of Housing and Urban Affairs  Clean & Green Technology
# SIH1515  Ministry of Housing and Urban Affairs          Smart Automation
# SIH1516  Ministry of Housing and Urban Affairs          Smart Automation
#
#          submisions                                        description  \
# SIH1278           5  Most of the Countries collect information/ mai...
# SIH1279          28  Cases differ substantially in the time require...
# SIH1280          56  Case Management Hearing, known as a Pre-Trial ...
# SIH1281         125  To create a fun, interactive, and engaging gam...
# SIH1282          30  To develop technology-driven solutions that ad...
# ...             ...                                                ...
# SIH1512          82  Electricity is the critical need for progress ...
# SIH1513          27  The problem at hand revolves around the manage...
# SIH1514           7  Water resources across the globe are slowly on...
# SIH1515         103  ln lndia, the number of vehicles is constanfly...
# SIH1516          23  A robust grievance redressal mechanism is a cr...
#
#         youtubeLink datasetLink
# SIH1278                      NA
# SIH1279                      NA
# SIH1280                      NA
# SIH1281                      NA
# SIH1282                      NA
# ...             ...         ...
# SIH1512                      NA
# SIH1513                      NA
# SIH1514                      NA
# SIH1515                      NA
# SIH1516                      NA
#
# [239 rows x 8 columns]

# %%
df.describe(include="all")
# Out:
#                      title  category                   organization  \
# count                  239       239                            239
# unique                 208         2                             37
# top     Student Innovation  Software  AICTE, MIC-Student Innovation
# freq                    32       181                             32
# mean                   NaN       NaN                            NaN
# std                    NaN       NaN                            NaN
# min                    NaN       NaN                            NaN
# 25%                    NaN       NaN                            NaN
# 50%                    NaN       NaN                            NaN
# 75%                    NaN       NaN                            NaN
# max                    NaN       NaN                            NaN
#
#          domainBucket  submisions  \
# count             239  239.000000
# unique             16         NaN
# top     Miscellaneous         NaN
# freq               42         NaN
# mean              NaN   31.016736
# std               NaN   33.207770
# min               NaN    1.000000
# 25%               NaN    7.000000
# 50%               NaN   20.000000
# 75%               NaN   41.000000
# max               NaN  134.000000
#
#                                               description youtubeLink  \
# count                                                 239         239
# unique                                                223           1
# top     Innovative ideas that help manage and generate...
# freq                                                    2         239
# mean                                                  NaN         NaN
# std                                                   NaN         NaN
# min                                                   NaN         NaN
# 25%                                                   NaN         NaN
# 50%                                                   NaN         NaN
# 75%                                                   NaN         NaN
# max                                                   NaN         NaN
#
#        datasetLink
# count          239
# unique           5
# top             NA
# freq           235
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 239 entries, SIH1278 to SIH1516
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         239 non-null    object
#  1   category      239 non-null    object
#  2   organization  239 non-null    object
#  3   domainBucket  239 non-null    object
#  4   submisions    239 non-null    object
#  5   description   239 non-null    object
#  6   youtubeLink   239 non-null    object
#  7   datasetLink   239 non-null    object
# dtypes: object(8)
# memory usage: 16.8+ KB
